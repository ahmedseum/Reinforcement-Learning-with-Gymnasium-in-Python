# %% [markdown]
# > Add blockquote![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Typer of Gemnasium Models***

# %%
# %pip install gymnasium
import gymnasium as gym
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#creating Environment
env = gym.make('FrozenLake-v1',is_slippery=False,render_mode='rgb_array')
#making an state
state,info=env.reset()
position = state

print(f"The position of the agent on the grid is {position}")
# Out:
# The position of the agent on the grid is 0

# %%
#creating a function , for showing the current state of the cartPole
def render():
    state_image = env.render()
    plt.imshow(state_image)
    plt.show()

# %%
render()

# %%
# 0: left , 1:Down ,2:Right,4:Up

actions = [1, 1, 2, 2, 1, 2]
state,info=env.reset(seed=42)
print(state)

for action in actions:
  state, reward, terminated, _, _ = env.step(action)
  print(f'For action {action} the State is {state}')
  # Render the environment
  render()
  if terminated:
  	print("You reached the goal!")
# Out:
# 0
# For action 1 the State is 4
# For action 1 the State is 8
# For action 2 the State is 9
# For action 2 the State is 10
# For action 1 the State is 14
# For action 2 the State is 15
# You reached the goal!
