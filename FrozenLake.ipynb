# %% [markdown]
# > Add blockquote![image.png](data:image/png;base64,...)

# %% [markdown]
# ***Typer of Gemnasium Models***

# %%
# %pip install gymnasium
import gymnasium as gym
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
#creating Environment
env = gym.make('FrozenLake', render_mode='rgb_array')
#making an state
state,info=env.reset(seed=42)
position = state

print(f"The position of the agent on the grid is {position}")
# Out:
# The position of the agent on the grid is 0
# /usr/local/lib/python3.11/dist-packages/gymnasium/envs/registration.py:527: UserWarning: WARN: Using the latest versioned environment `FrozenLake-v1` instead of the unversioned environment `FrozenLake`.
#   logger.warn(

# %%
#creating a function , for showing the current state of the cartPole
def render():
    state_image = env.render()
    plt.imshow(state_image)
    plt.show()

# %%
render()

# %%
# Define the sequence of actions
actions = [1, 1, 2, 2, 1, 2]

for action in actions:
  # Execute each action
  state, reward, terminated, _, _ = env.step(action)
  # Render the environment
  render()
  if terminated:
  	print("You reached the goal!")
# Out:
# You reached the goal!
# You reached the goal!
# You reached the goal!
# You reached the goal!
# You reached the goal!
